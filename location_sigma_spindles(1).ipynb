# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoBrandstetterr/location-of-the-sigma-spindles-in-EEG/blob/keim-job/location_sigma_spindles(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nicolas Brandstetter
# Felipe Keim
#
# Predicción de inicio y final de un evento de huso del sueño

# %%
#Imports
import numpy as np
import torch
from torch import nn
import torchvision
import matplotlib.pyplot as plt
import os
import sys
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import math 
from IPython.display import clear_output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # loading data

# %%
# !unzip "/content/drive/MyDrive/Cursos/Primavera 2022/Inteligencia/Proyecto/Data/Localización de husos sigma.zip" -d "/content/data"
clear_output() 
print('****Base de datos descomprimida****')
# Out:
# ****Base de datos descomprimida****

# %%
test_marks    = np.load('data/Localización de husos sigma en el EEG del sueño/test_marks.npy')
test_signals  = np.load('data/Localización de husos sigma en el EEG del sueño/test_signals.npy')
train_marks   = np.load('data/Localización de husos sigma en el EEG del sueño/train_marks.npy')
train_signals = np.load('data/Localización de husos sigma en el EEG del sueño/train_signals.npy')
val_marks     = np.load('data/Localización de husos sigma en el EEG del sueño/val_marks.npy')
val_signals   = np.load('data/Localización de husos sigma en el EEG del sueño/val_signals.npy')

# %%
scaler = StandardScaler()
scaler = scaler.fit(np.concatenate((test_signals,train_signals,val_signals)))

val_signals_normalized = scaler.transform(val_signals)
test_signals_normalized = scaler.transform(test_signals)
train_signals_normalized = scaler.transform(train_signals)

# %%
val_marks = torch.tensor(val_marks)
test_marks = torch.tensor(test_marks)
train_marks = torch.tensor(train_marks)

val_signals = torch.tensor(val_signals_normalized)
test_signals = torch.tensor(test_signals_normalized)
train_signals = torch.tensor(train_signals_normalized)

# %% [markdown]
# ## Creating Dataset

# %%
train_ds = torch.utils.data.TensorDataset(train_signals, train_marks)
val_ds = torch.utils.data.TensorDataset(val_signals, val_marks)
test_ds = torch.utils.data.TensorDataset(test_signals, test_marks)

# %% [markdown]
# # entrenamiento y visualización

# %% [markdown]
# ## Curves

# %%
def show_curves(curves):
    fig, ax = plt.subplots(1, 2, figsize=(13, 5))
    fig.set_facecolor('white')

    epochs = np.arange(len(curves["val_loss"])) + 1

    ax[0].plot(epochs, curves['val_loss'], label='validation')
    ax[0].plot(epochs, curves['train_loss'], label='training')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')
    ax[0].set_title('Loss evolution during training')
    ax[0].legend()

    ax[1].plot(epochs, curves['val_acc'], label='validation')
    ax[1].plot(epochs, curves['train_acc'], label='training')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Accuracy')
    ax[1].set_title('Accuracy evolution during training')
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## IOU

# %%
SMOOTH = 1e-6

def iou_pytorch(y_predicted: torch.Tensor, y_vals: torch.Tensor,eva=False):

    
    
    
    largo=len(y_vals)
    error_array=np.zeros(largo)
    count=0
    for pred,y_val in zip(y_predicted,y_vals):
        pred=pred.squeeze(0)
        intervalo_inter = [max(pred[0],y_val[0]),min(pred[1],y_val[1])]
        rest = intervalo_inter[1] - intervalo_inter[0]
        inter = rest if rest>0 else 0

        len_predicted = pred[1] - pred[0]
        len_val = y_val[1] - y_val[0]
        union = len_predicted + len_val - inter
        error_array[count]=(inter/(union+1e-6))
        count+=1
        
    return torch.tensor(1-np.mean(error_array),requires_grad=True)

# %%
SMOOTH = 1e-6

def iou_pytorch(outputs: torch.Tensor, labels: torch.Tensor):
    # You can comment out this line if you are passing tensors of equal shape
    # But if you are passing output from UNet or something it will most probably
    # be with the BATCH x 1 x H x W shape
    #outputs = outputs.squeeze(1)  # BATCH x 1 x H x W => BATCH x H x W
    
    intersection = (outputs & labels).float().sum((1, 2))  # Will be zero if Truth=0 or Prediction=0
    union = (outputs | labels).float().sum((1, 2))         # Will be zzero if both are 0
    
    iou = (intersection + SMOOTH) / (union + SMOOTH)  # We smooth our devision to avoid 0/0
    
    thresholded = torch.clamp(20 * (iou - 0.5), 0, 10).ceil() / 10  # This is equal to comparing with thresolds
    
    return thresholded  # Or thresholded.mean() if you are interested in average across the batch

# %%
real = torch.tensor([[200, 300], [100, 120]])
pred = torch.tensor([[250, 400], [140, 160]])

#iou_pytorch(a, b)
(real & pred)
# Out:
# tensor([[200, 256],
#         [  4,  32]])

# %% [markdown]
# ## Evaluation

# %%
def evaluate(val_loader, model, criterion, use_gpu,delta):
    cumulative_loss = 0
    cumulative_predictions = 0
    data_count = 0
    y_predicted=[]
    error_list=[]
    delta=math.sqrt(delta)
    for x_val, y_val in val_loader:
        for x,y in zip(x_val,y_val):   
            x=x.unsqueeze(0)
            x=x.unsqueeze(0)
            if use_gpu:
                x = x.cuda()
                y = y.cuda()
            y_pred=model(x)
            y_pred=y_pred.reshape(2)
            #print('y_pred.unsqueeze(0)', y_pred.unsqueeze(0))
            #print('y.unsqueeze(0)', y.unsqueeze(0))
            err = criterion(y_pred.unsqueeze(0),y.unsqueeze(0)) ###,eva=True)     ################
            error_list.append(err)
            y_predicted.append(y_pred)
            cumulative_predictions += (err<delta)
            cumulative_loss += err
        data_count = x_val.shape[0]

    val_acc = cumulative_predictions / data_count  #data_count = len(y_val)
    val_loss = cumulative_loss/len(y_val)
    return val_acc, val_loss

# %% [markdown]
# ## Training set up

# %% [markdown]
# ### Train step

# %%
def train_step(x_batch, y_batch, model, optimizer, criterion, use_gpu,delta):
    # Predicción
    #y_predicted=[]
    #for pred in x_batch:
    #    pred=pred.unsqueeze(0)
    #    pred=pred.unsqueeze(0)
    #   y_predicted.append(model(pred))    ### NO ES NECESARIO, EL MODELO DEBERIA PROCESAR EL BATCH COMPLETO SI LAS DIMENSIONES CORRESPONDEN A COMO LO TOMA PYTORCH

    delta=math.sqrt(delta)
    y_predicted = model(x_batch.unsqueeze(1))     ### DIM (batch_size, channels, data_len)

    # Cálculo de loss
    print('y_predicted.squeeze(): ', y_predicted.squeeze())
    print('y_batch.float(): ', y_batch.float())
    
    loss = criterion(y_predicted.squeeze(), y_batch.float())   ### y_predicted e y_batch DEBEN TENER IGUAL DIM ####################
    # Calculo de VP
    VP=int((loss<=delta))

    # Actualización de parámetros
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return y_predicted, loss, VP

# %% [markdown]
# ### Train Model

# %%
def train_model(
    model,
    train_dataset,
    val_dataset,
    epochs,
    criterion,
    batch_size,
    lr,
    n_evaluations_per_epoch=6,
    use_gpu=False,
    data_augmentation=False,
    delta=0.01
):

    if use_gpu:
        model.cuda()

    # Definición de dataloader
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=use_gpu)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=len(val_dataset), shuffle=False, pin_memory=use_gpu)

    # for i,x in enumerate(train_loader):
    #     a=[0,1,2,3,4]
    #     if i in a:
    #         print("loader: ",x[1])

    # Optimizador
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Listas para guardar curvas de entrenamiento
    curves = {
        "train_acc": [],
        "val_acc": [],
        "train_loss": [],
        "val_loss": [],
    }

    t0 = time.perf_counter()

    iteration = 0

    n_batches = len(train_loader)

    for epoch in range(epochs):
        print(f"\rEpoch {epoch + 1}/{epochs}")
        cumulative_train_loss = 0
        cumulative_train_corrects = 0
        train_loss_count = 0
        train_acc_count = 0


        # Entrenamiento del modelo
        model.train()

        for i, (x_batch, y_batch) in enumerate(train_loader):
            if use_gpu:
                x_batch = x_batch.cuda()
                y_batch = y_batch.cuda()

            y_predicted, loss,vp = train_step(x_batch, y_batch, model, optimizer, criterion, use_gpu,delta)

            cumulative_train_loss += loss.item()
            train_loss_count += 1
            train_acc_count += y_batch.shape[0]

            # Calculamos número de aciertos
            #class_prediction = torch.argmax(y_predicted, axis=1).long()
            cumulative_train_corrects += vp

            if (i % (n_batches // n_evaluations_per_epoch) == 0) and (i > 0):
                train_loss = cumulative_train_loss / train_loss_count
                train_acc = cumulative_train_corrects / (train_acc_count/len(y_batch))   #multiplique por el batch size

                print(f"Iteration {iteration} - Batch {i}/{len(train_loader)} - Train loss: {train_loss}, Train acc: {train_acc}")
            iteration += 1


        model.eval()
        with torch.no_grad():
            val_acc, val_loss = evaluate(val_loader, model, criterion, use_gpu,delta)

        print(f"Val loss: {val_loss}, Val acc: {val_acc}")

        train_loss = cumulative_train_loss / train_loss_count
        train_acc = 4*cumulative_train_corrects / train_acc_count   #multiplique por 4 por ahora

        curves["train_acc"].append(train_acc)
        curves["val_acc"].append(val_acc)
        curves["train_loss"].append(train_loss)
        curves["val_loss"].append(val_loss)

    print()
    print(f"Tiempo total de entrenamiento: {time.perf_counter() - t0:.4f} [s]")

    model.cpu()

    # if data_augmentation:
    #     train_dataset.dataset.transform = original_transform

    return curves

# %% [markdown]
# # Models Definition

# %% [markdown]
# ## Conv1dModel

# %%
class CNN1d_Model(nn.Module):
    eva=False
    def __init__(
        self,
        dropout_p,
        input_size=1,
    ):
        
        super().__init__()
        self.conv_blocks = nn.Sequential(
            
            nn.Conv1d(input_size, 1, kernel_size=1, stride=1, padding="same"),

            nn.Conv1d(input_size, 8, kernel_size=3, stride=1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(8, 16,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(16,32,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32,64,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64,128,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128,256,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(5),

            nn.Conv1d(256,256,kernel_size=3, stride = 1, padding="same"),
            nn.ReLU(),
            nn.MaxPool1d(5),

            nn.Conv1d(256,2,kernel_size=3, stride = 1, padding="same"),
            
        )

    def forward(self, x,evaa=False):
        return self.conv_blocks(x)

# %% [markdown]
# # Training

# %%
lr = 0.001
batch_size = 4
#criterion = iou_pytorch
criterion = torch.nn.MSELoss()
epochs = 2

# %%
CNN1d = CNN1d_Model(dropout_p=0.5)
curves = train_model(
    CNN1d,
    train_ds,
    val_ds,
    epochs,
    criterion,
    batch_size,
    lr,
    use_gpu=False,
    data_augmentation=False,
    delta=5000*5000
)
show_curves(curves)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# y_batch.float():  tensor([[287., 452.],
#         [235., 468.],
#         [319., 464.],
#         [198., 397.]])
# y_predicted.squeeze():  tensor([[281.5339, 436.1542],
#         [296.2232, 456.7754],
#         [293.4539, 454.0099],
#         [284.4511, 438.8735]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[234., 449.],
#         [395., 590.],
#         [267., 432.],
#         [421., 569.]])
# y_predicted.squeeze():  tensor([[297.9808, 460.0170],
#         [252.2916, 391.6128],
#         [285.7509, 441.8001],
#         [251.4641, 390.0529]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[459., 580.],
#         [196., 403.],
#         [471., 628.],
#         [251., 408.]])
# y_predicted.squeeze():  tensor([[263.0305, 407.3443],
#         [267.8013, 415.8660],
#         [265.5016, 411.6154],
#         [260.6310, 403.2298]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[300., 548.],
#         [228., 386.],
#         [326., 511.],
#         [289., 476.]])
# y_predicted.squeeze():  tensor([[285.5678, 444.4324],
#         [286.3559, 443.0718],
#         [256.2772, 398.5941],
#         [261.7279, 406.6802]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[227., 502.],
#         [401., 579.],
#         [297., 452.],
#         [274., 410.]])
# y_predicted.squeeze():  tensor([[286.9869, 444.4069],
#         [300.9294, 467.4368],
#         [271.6539, 422.2552],
#         [300.0652, 466.2286]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[478., 608.],
#         [333., 441.],
#         [337., 461.],
#         [285., 558.]])
# y_predicted.squeeze():  tensor([[278.8131, 434.1129],
#         [292.0438, 453.8296],
#         [279.9439, 435.8124],
#         [277.0821, 430.7689]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[267., 418.],
#         [393., 590.],
#         [248., 369.],
#         [174., 356.]])
# y_predicted.squeeze():  tensor([[298.7922, 462.6706],
#         [295.8601, 460.0652],
#         [283.3393, 439.9002],
#         [298.8052, 463.4288]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[531., 660.],
#         [387., 533.],
#         [169., 303.],
#         [405., 542.]])
# y_predicted.squeeze():  tensor([[330.4310, 511.5149],
#         [315.2365, 488.8440],
#         [299.7915, 464.7642],
#         [302.4185, 469.0396]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[385., 601.],
#         [402., 640.],
#         [343., 455.],
#         [474., 636.]])
# y_predicted.squeeze():  tensor([[308.9040, 471.5884],
#         [304.0653, 463.4013],
#         [312.2558, 475.9984],
#         [299.8185, 457.8088]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[148., 288.],
#         [350., 488.],
#         [327., 471.],
#         [192., 321.]])
# y_predicted.squeeze():  tensor([[344.4452, 525.0272],
#         [318.0161, 482.8510],
#         [309.9827, 472.8182],
#         [307.5480, 468.0427]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[250., 393.],
#         [412., 644.],
#         [248., 427.],
#         [316., 474.]])
# y_predicted.squeeze():  tensor([[329.2906, 500.9854],
#         [340.3387, 514.8592],
#         [319.1446, 485.5019],
#         [342.5439, 519.6495]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[180., 473.],
#         [496., 658.],
#         [163., 317.],
#         [380., 514.]])
# y_predicted.squeeze():  tensor([[343.5399, 520.5544],
#         [321.4835, 488.2260],
#         [331.7235, 502.8433],
#         [338.5984, 515.1291]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[400., 582.],
#         [160., 333.],
#         [404., 562.],
#         [226., 414.]])
# y_predicted.squeeze():  tensor([[352.0395, 533.6951],
#         [333.4192, 506.6507],
#         [337.8212, 511.4942],
#         [308.0918, 466.9750]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[438., 589.],
#         [341., 472.],
#         [481., 622.],
#         [323., 456.]])
# y_predicted.squeeze():  tensor([[300.6864, 455.4894],
#         [340.9184, 516.9446],
#         [329.7894, 498.7408],
#         [344.0993, 521.9175]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[463., 586.],
#         [338., 506.],
#         [496., 636.],
#         [287., 420.]])
# y_predicted.squeeze():  tensor([[336.8871, 509.5219],
#         [322.6312, 487.0148],
#         [346.1963, 521.3706],
#         [347.1869, 524.1230]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[286., 462.],
#         [178., 333.],
#         [430., 544.],
#         [326., 473.]])
# y_predicted.squeeze():  tensor([[344.7443, 517.8343],
#         [380.8507, 571.1779],
#         [349.5905, 525.0347],
#         [321.6662, 482.6114]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[308., 500.],
#         [350., 508.],
#         [173., 297.],
#         [146., 254.]])
# y_predicted.squeeze():  tensor([[334.7910, 502.4730],
#         [310.2696, 464.8839],
#         [345.5357, 517.5314],
#         [345.9081, 517.8779]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[254., 456.],
#         [234., 345.],
#         [408., 588.],
#         [351., 503.]])
# y_predicted.squeeze():  tensor([[321.5388, 482.4833],
#         [311.3189, 466.2813],
#         [309.7406, 464.0003],
#         [373.3308, 557.5776]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[178., 412.],
#         [278., 433.],
#         [301., 480.],
#         [425., 563.]])
# y_predicted.squeeze():  tensor([[310.5708, 466.0458],
#         [332.5714, 496.7005],
#         [303.8128, 455.0578],
#         [326.2323, 487.3931]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[228., 453.],
#         [458., 635.],
#         [147., 318.],
#         [472., 647.]])
# y_predicted.squeeze():  tensor([[278.4078, 416.8987],
#         [304.1693, 454.9329],
#         [302.1608, 454.0572],
#         [294.9528, 442.1884]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[209., 374.],
#         [418., 566.],
#         [226., 378.],
#         [312., 466.]])
# y_predicted.squeeze():  tensor([[294.0205, 440.0436],
#         [276.2888, 415.0691],
#         [278.9518, 418.1301],
#         [297.9644, 445.6017]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[480., 638.],
#         [244., 372.],
#         [314., 489.],
#         [460., 642.]])
# y_predicted.squeeze():  tensor([[305.3823, 456.2249],
#         [283.5265, 425.9740],
#         [313.6804, 469.6557],
#         [310.3484, 464.0420]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[248., 391.],
#         [243., 404.],
#         [334., 530.],
#         [448., 600.]])
# y_predicted.squeeze():  tensor([[291.3843, 437.2617],
#         [317.4570, 473.8690],
#         [307.3483, 460.0661],
#         [289.8675, 434.7093]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[264., 401.],
#         [475., 599.],
#         [222., 367.],
#         [183., 361.]])
# y_predicted.squeeze():  tensor([[302.4268, 452.8382],
#         [314.7424, 471.2029],
#         [287.5095, 430.6530],
#         [311.6092, 467.5811]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[350., 495.],
#         [314., 522.],
#         [155., 317.],
#         [243., 415.]])
# y_predicted.squeeze():  tensor([[286.8176, 429.7192],
#         [297.0409, 444.5392],
#         [317.9215, 474.7104],
#         [308.7905, 462.2620]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[256., 360.],
#         [278., 389.],
#         [467., 639.],
#         [381., 616.]])
# y_predicted.squeeze():  tensor([[298.7582, 448.7629],
#         [313.5718, 471.1772],
#         [288.7675, 433.5843],
#         [333.8459, 499.0223]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[189., 397.],
#         [147., 355.],
#         [306., 447.],
#         [440., 649.]])
# y_predicted.squeeze():  tensor([[295.4210, 443.5395],
#         [297.0475, 447.2350],
#         [326.1371, 490.9403],
#         [331.5759, 497.3511]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[205., 316.],
#         [150., 335.],
#         [243., 485.],
#         [206., 344.]])
# y_predicted.squeeze():  tensor([[282.8831, 428.1743],
#         [301.2007, 455.7718],
#         [307.0149, 464.0249],
#         [294.6180, 445.3668]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[310., 442.],
#         [302., 447.],
#         [389., 571.],
#         [380., 563.]])
# y_predicted.squeeze():  tensor([[286.0029, 435.9114],
#         [304.5866, 462.4967],
#         [285.1574, 433.1792],
#         [278.5591, 423.3256]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[238., 382.],
#         [349., 539.],
#         [212., 377.],
#         [150., 271.]])
# y_predicted.squeeze():  tensor([[307.8408, 469.8304],
#         [277.2647, 425.0089],
#         [306.4944, 466.3889],
#         [300.8417, 459.1136]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[400., 567.],
#         [151., 288.],
#         [473., 655.],
#         [352., 532.]])
# y_predicted.squeeze():  tensor([[294.5823, 450.5016],
#         [294.9819, 451.3548],
#         [285.9126, 438.4085],
#         [291.4851, 447.3853]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[431., 560.],
#         [442., 574.],
#         [167., 352.],
#         [354., 511.]])
# y_predicted.squeeze():  tensor([[292.8921, 451.2629],
#         [335.5132, 513.0906],
#         [276.7794, 425.8453],
#         [282.8944, 435.3070]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[258., 374.],
#         [479., 622.],
#         [253., 388.],
#         [171., 316.]])
# y_predicted.squeeze():  tensor([[284.4079, 438.1099],
#         [309.3471, 476.1638],
#         [277.4906, 426.4530],
#         [290.8041, 447.6344]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[203., 372.],
#         [148., 383.],
#         [144., 290.],
#         [213., 343.]])
# y_predicted.squeeze():  tensor([[280.5904, 432.8408],
#         [296.0913, 456.5498],
#         [299.2738, 460.8061],
#         [285.9955, 442.1465]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[176., 361.],
#         [432., 560.],
#         [452., 644.],
#         [288., 466.]])
# y_predicted.squeeze():  tensor([[297.5840, 459.2470],
#         [270.2113, 418.6740],
#         [298.2928, 460.4885],
#         [295.9431, 457.9278]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[493., 623.],
#         [250., 405.],
#         [452., 614.],
#         [404., 582.]])
# y_predicted.squeeze():  tensor([[279.3751, 433.0240],
#         [313.3946, 481.6044],
#         [299.0768, 462.1919],
#         [295.7986, 457.0536]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[236., 417.],
#         [529., 644.],
#         [170., 341.],
#         [175., 333.]])
# y_predicted.squeeze():  tensor([[326.6853, 504.0010],
#         [312.9405, 481.7169],
#         [299.7675, 464.4431],
#         [342.3411, 527.5497]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[384., 610.],
#         [486., 612.],
#         [245., 403.],
#         [440., 631.]])
# y_predicted.squeeze():  tensor([[305.3821, 472.0030],
#         [326.1253, 504.6458],
#         [339.2337, 521.9170],
#         [366.3091, 562.2278]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[331., 526.],
#         [231., 503.],
#         [417., 602.],
#         [539., 650.]])
# y_predicted.squeeze():  tensor([[340.5451, 523.0452],
#         [336.8463, 516.9732],
#         [344.1802, 528.1682],
#         [364.6832, 559.9619]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[196., 425.],
#         [359., 543.],
#         [429., 613.],
#         [391., 554.]])
# y_predicted.squeeze():  tensor([[357.7379, 547.7952],
#         [362.3460, 555.4316],
#         [337.7998, 518.9722],
#         [356.1994, 548.6626]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[328., 490.],
#         [370., 491.],
#         [278., 448.],
#         [258., 450.]])
# y_predicted.squeeze():  tensor([[352.4157, 539.5672],
#         [386.6526, 590.0755],
#         [409.2208, 626.0438],
#         [328.2808, 502.5998]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[281., 459.],
#         [396., 554.],
#         [285., 565.],
#         [147., 302.]])
# y_predicted.squeeze():  tensor([[341.5876, 521.6820],
#         [354.0448, 543.9742],
#         [357.5340, 547.3083],
#         [382.4239, 583.8214]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[494., 638.],
#         [273., 456.],
#         [157., 301.],
#         [421., 602.]])
# y_predicted.squeeze():  tensor([[337.3984, 516.8802],
#         [344.4297, 530.0124],
#         [353.1888, 542.3669],
#         [321.8864, 494.1523]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[363., 562.],
#         [195., 325.],
#         [247., 489.],
#         [299., 440.]])
# y_predicted.squeeze():  tensor([[355.1540, 542.4191],
#         [319.5404, 491.7007],
#         [334.2585, 514.8695],
#         [319.4926, 491.3741]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[483., 604.],
#         [181., 331.],
#         [148., 340.],
#         [283., 471.]])
# y_predicted.squeeze():  tensor([[367.1048, 563.8309],
#         [349.6123, 538.0935],
#         [300.7101, 464.1877],
#         [344.4524, 527.4484]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[428., 613.],
#         [374., 567.],
#         [291., 489.],
#         [521., 659.]])
# y_predicted.squeeze():  tensor([[299.8669, 463.0697],
#         [320.9103, 496.9565],
#         [325.7870, 502.3572],
#         [276.2747, 427.3015]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[193., 348.],
#         [241., 453.],
#         [377., 541.],
#         [235., 390.]])
# y_predicted.squeeze():  tensor([[279.1270, 432.7292],
#         [339.9874, 524.6133],
#         [271.1538, 420.2398],
#         [280.1706, 434.1144]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[171., 387.],
#         [366., 541.],
#         [172., 313.],
#         [266., 451.]])
# y_predicted.squeeze():  tensor([[277.8109, 430.4624],
#         [264.6894, 412.6819],
#         [316.7225, 491.7784],
#         [302.3334, 469.2356]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[411., 605.],
#         [267., 398.],
#         [185., 323.],
#         [392., 592.]])
# y_predicted.squeeze():  tensor([[275.6352, 429.3998],
#         [274.2130, 425.8816],
#         [260.9243, 407.5600],
#         [281.0799, 438.2470]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[384., 585.],
#         [447., 625.],
#         [257., 472.],
#         [305., 531.]])
# y_predicted.squeeze():  tensor([[271.7841, 425.9674],
#         [252.7314, 396.3471],
#         [292.3666, 455.8092],
#         [250.2051, 391.1383]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[247., 418.],
#         [302., 453.],
#         [385., 590.],
#         [194., 370.]])
# y_predicted.squeeze():  tensor([[291.5289, 457.3495],
#         [256.2458, 402.9638],
#         [264.4887, 412.6768],
#         [299.7297, 467.8270]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[268., 563.],
#         [181., 435.],
#         [471., 617.],
#         [454., 637.]])
# y_predicted.squeeze():  tensor([[260.6365, 409.5750],
#         [270.3912, 425.7449],
#         [268.4412, 422.2952],
#         [281.1787, 441.8486]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[198., 363.],
#         [180., 318.],
#         [168., 346.],
#         [330., 544.]])
# y_predicted.squeeze():  tensor([[270.8983, 428.7495],
#         [263.9426, 418.3217],
#         [313.6951, 494.0619],
#         [258.0087, 408.2152]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[172., 339.],
#         [234., 406.],
#         [361., 562.],
#         [223., 357.]])
# Iteration 1674 - Batch 558/1116 - Train loss: 11519.281522747442, Train acc: 0.15384615384615385
# y_predicted.squeeze():  tensor([[267.0852, 423.9568],
#         [338.5622, 538.1115],
#         [284.4660, 452.6329],
#         [307.4327, 488.5299]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[271., 416.],
#         [220., 580.],
#         [176., 458.],
#         [335., 519.]])
# y_predicted.squeeze():  tensor([[266.9734, 428.6526],
#         [291.7789, 468.0997],
#         [265.6666, 427.2563],
#         [274.6302, 439.8535]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[170., 323.],
#         [275., 460.],
#         [215., 413.],
#         [330., 491.]])
# y_predicted.squeeze():  tensor([[326.8685, 526.8259],
#         [286.6123, 464.9822],
#         [266.5866, 431.8283],
#         [258.2725, 417.9434]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[386., 614.],
#         [233., 431.],
#         [233., 441.],
#         [237., 373.]])
# y_predicted.squeeze():  tensor([[286.7803, 470.1321],
#         [285.9283, 467.8481],
#         [305.2397, 496.4352],
#         [269.3327, 442.0031]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[204., 422.],
#         [273., 508.],
#         [368., 585.],
#         [216., 384.]])
# y_predicted.squeeze():  tensor([[269.1956, 445.0408],
#         [260.2564, 431.7032],
#         [295.6426, 485.9385],
#         [270.9247, 448.0445]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[305., 481.],
#         [248., 410.],
#         [435., 562.],
#         [284., 472.]])
# y_predicted.squeeze():  tensor([[285.5781, 472.2112],
#         [287.6446, 476.6339],
#         [285.6387, 474.4110],
#         [285.7438, 472.6249]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[467., 589.],
#         [401., 531.],
#         [299., 464.],
#         [510., 655.]])
# y_predicted.squeeze():  tensor([[295.2433, 490.0307],
#         [284.7081, 473.5435],
#         [275.0615, 459.1502],
#         [283.0806, 472.3595]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[356., 497.],
#         [351., 480.],
#         [248., 403.],
#         [182., 473.]])
# y_predicted.squeeze():  tensor([[307.4560, 508.5369],
#         [300.2998, 498.4084],
#         [306.5053, 507.9062],
#         [277.8731, 462.3528]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[210., 322.],
#         [181., 319.],
#         [214., 369.],
#         [370., 509.]])
# y_predicted.squeeze():  tensor([[308.8197, 476.0460],
#         [283.0066, 438.1937],
#         [313.7374, 483.1485],
#         [299.0951, 462.7227]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[407., 572.],
#         [259., 427.],
#         [193., 422.],
#         [157., 295.]])
# y_predicted.squeeze():  tensor([[305.3731, 468.7306],
#         [280.8589, 434.2788],
#         [305.3744, 468.3889],
#         [268.5356, 414.4326]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[413., 558.],
#         [257., 412.],
#         [400., 548.],
#         [151., 303.]])
# y_predicted.squeeze():  tensor([[263.3435, 405.1161],
#         [312.2477, 477.2565],
#         [302.5931, 462.7864],
#         [270.7403, 416.3268]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[186., 368.],
#         [404., 596.],
#         [405., 553.],
#         [173., 347.]])
# y_predicted.squeeze():  tensor([[305.6437, 464.4145],
#         [249.2802, 381.1566],
#         [289.1854, 440.0220],
#         [292.6436, 445.7698]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[470., 659.],
#         [145., 283.],
#         [481., 655.],
#         [423., 564.]])
# y_predicted.squeeze():  tensor([[286.2528, 433.8120],
#         [308.4924, 466.3419],
#         [278.8699, 424.4472],
#         [277.9389, 424.1789]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[439., 584.],
#         [486., 622.],
#         [325., 516.],
#         [233., 344.]])
# y_predicted.squeeze():  tensor([[298.1637, 451.4258],
#         [309.0627, 467.1679],
#         [303.6733, 459.3252],
#         [299.6690, 454.0941]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[192., 396.],
#         [214., 423.],
#         [228., 361.],
#         [160., 337.]])
# y_predicted.squeeze():  tensor([[312.5410, 469.7314],
#         [318.7740, 478.2804],
#         [288.8510, 436.7616],
#         [341.6252, 511.4778]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[373., 499.],
#         [401., 600.],
#         [269., 370.],
#         [471., 592.]])
# y_predicted.squeeze():  tensor([[292.1207, 438.5797],
#         [312.4579, 467.7480],
#         [324.2686, 487.1179],
#         [307.9276, 462.9450]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[244., 388.],
#         [384., 522.],
#         [322., 472.],
#         [281., 449.]])
# y_predicted.squeeze():  tensor([[323.0232, 484.1780],
#         [293.3006, 438.4948],
#         [347.6116, 517.1219],
#         [296.1307, 444.1171]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[156., 356.],
#         [166., 315.],
#         [404., 558.],
#         [147., 262.]])
# y_predicted.squeeze():  tensor([[298.6501, 444.5127],
#         [318.3789, 474.9922],
#         [294.0138, 438.7028],
#         [342.5139, 509.2909]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[173., 342.],
#         [314., 484.],
#         [153., 306.],
#         [392., 560.]])
# y_predicted.squeeze():  tensor([[350.9683, 520.5012],
#         [304.8487, 456.6956],
#         [322.1591, 480.7375],
#         [377.8781, 561.0518]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[441., 609.],
#         [167., 305.],
#         [196., 335.],
#         [376., 606.]])
# y_predicted.squeeze():  tensor([[300.2665, 449.8881],
#         [305.0263, 457.1244],
#         [327.4653, 487.0412],
#         [286.9341, 429.1507]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[213., 439.],
#         [250., 416.],
#         [388., 599.],
#         [200., 392.]])
# y_predicted.squeeze():  tensor([[316.2239, 473.3560],
#         [291.6350, 439.4748],
#         [342.5718, 512.1191],
#         [305.4994, 458.2391]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[233., 388.],
#         [513., 657.],
#         [226., 365.],
#         [468., 578.]])
# y_predicted.squeeze():  tensor([[311.0288, 477.9940],
#         [310.2810, 477.3309],
#         [278.1017, 428.4695],
#         [285.8680, 442.4745]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[420., 571.],
#         [490., 634.],
#         [403., 541.],
#         [297., 472.]])
# y_predicted.squeeze():  tensor([[281.4129, 431.8531],
#         [301.0931, 461.5192],
#         [298.7391, 457.7792],
#         [328.8487, 501.3882]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[205., 334.],
#         [357., 513.],
#         [277., 472.],
#         [477., 635.]])
# y_predicted.squeeze():  tensor([[295.7318, 451.5355],
#         [314.8609, 479.4261],
#         [348.4791, 527.1813],
#         [316.1030, 479.8780]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[208., 360.],
#         [303., 448.],
#         [373., 659.],
#         [341., 543.]])
# y_predicted.squeeze():  tensor([[336.5182, 508.8549],
#         [374.8594, 563.2045],
#         [328.7941, 498.4767],
#         [328.2779, 495.8265]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[305., 504.],
#         [433., 639.],
#         [215., 383.],
#         [350., 461.]])
# y_predicted.squeeze():  tensor([[379.5356, 568.9295],
#         [378.6794, 568.0666],
#         [361.2811, 543.6171],
#         [337.9399, 510.8047]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[514., 618.],
#         [476., 630.],
#         [361., 574.],
#         [252., 501.]])
# y_predicted.squeeze():  tensor([[345.9501, 519.1395],
#         [381.6554, 572.0368],
#         [368.3604, 552.1885],
#         [371.8101, 556.1836]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[251., 426.],
#         [367., 496.],
#         [528., 639.],
#         [413., 550.]])
# y_predicted.squeeze():  tensor([[362.3500, 540.0140],
#         [385.4617, 573.9755],
#         [417.2952, 619.5685],
#         [407.6458, 606.2400]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[333., 455.],
#         [248., 379.],
#         [370., 494.],
#         [322., 538.]])
# y_predicted.squeeze():  tensor([[371.6987, 551.5175],
#         [434.6250, 639.9666],
#         [388.7353, 577.2750],
#         [398.6072, 587.9194]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[332., 417.],
#         [468., 619.],
#         [238., 479.],
#         [418., 548.]])
# y_predicted.squeeze():  tensor([[403.6890, 592.3180],
#         [367.6662, 541.9221],
#         [362.2167, 534.6014],
#         [365.6989, 540.8979]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[389., 591.],
#         [152., 384.],
#         [209., 368.],
#         [257., 418.]])
# y_predicted.squeeze():  tensor([[375.2693, 553.6691],
#         [362.4399, 536.0482],
#         [352.1896, 518.1151],
#         [363.9431, 534.0662]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[167., 381.],
#         [153., 364.],
#         [313., 447.],
#         [393., 557.]])
# y_predicted.squeeze():  tensor([[341.8674, 503.8621],
#         [378.0371, 556.2448],
#         [304.2307, 449.8745],
#         [371.9665, 546.9042]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[384., 553.],
#         [373., 558.],
#         [151., 296.],
#         [434., 595.]])
# y_predicted.squeeze():  tensor([[321.2045, 475.9579],
#         [319.3800, 472.3584],
#         [308.4586, 455.5099],
#         [324.8724, 480.1610]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[362., 537.],
#         [345., 529.],
#         [523., 652.],
#         [429., 620.]])
# y_predicted.squeeze():  tensor([[299.3339, 445.8362],
#         [299.9254, 443.7077],
#         [330.3358, 487.8177],
#         [277.2366, 409.5452]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[323., 605.],
#         [397., 545.],
#         [320., 544.],
#         [470., 644.]])
# y_predicted.squeeze():  tensor([[319.1145, 484.6199],
#         [317.7478, 485.9890],
#         [299.6830, 457.6720],
#         [333.1607, 506.8726]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[366., 517.],
#         [169., 307.],
#         [157., 312.],
#         [208., 370.]])
# y_predicted.squeeze():  tensor([[327.9203, 501.2267],
#         [313.7499, 480.9899],
#         [324.5598, 497.6106],
#         [351.6475, 532.5261]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[365., 497.],
#         [321., 489.],
#         [271., 446.],
#         [519., 648.]])
# y_predicted.squeeze():  tensor([[321.3133, 493.6778],
#         [333.7901, 509.8457],
#         [345.0252, 528.7278],
#         [289.6133, 445.6981]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[160., 294.],
#         [413., 609.],
#         [382., 584.],
#         [169., 340.]])
# y_predicted.squeeze():  tensor([[300.9850, 467.9934],
#         [299.1275, 465.9344],
#         [304.8222, 474.4107],
#         [294.7249, 459.1042]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[163., 364.],
#         [203., 472.],
#         [213., 433.],
#         [190., 359.]])
# y_predicted.squeeze():  tensor([[283.7143, 444.3773],
#         [318.8612, 494.5298],
#         [284.7264, 447.8120],
#         [301.0594, 473.8703]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[222., 397.],
#         [439., 620.],
#         [225., 399.],
#         [255., 459.]])
# y_predicted.squeeze():  tensor([[299.5641, 473.0710],
#         [299.9757, 470.9153],
#         [304.4268, 480.5781],
#         [270.3728, 427.0966]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[309., 453.],
#         [478., 653.],
#         [379., 539.],
#         [319., 490.]])
# y_predicted.squeeze():  tensor([[275.5110, 437.7241],
#         [264.8144, 424.0516],
#         [263.4081, 421.4333],
#         [295.2219, 463.8051]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[365., 540.],
#         [319., 487.],
#         [144., 349.],
#         [507., 660.]])
# y_predicted.squeeze():  tensor([[278.9988, 446.3111],
#         [268.9034, 429.1856],
#         [260.2432, 419.5714],
#         [336.2933, 532.6996]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[148., 312.],
#         [336., 568.],
#         [151., 268.],
#         [392., 547.]])
# y_predicted.squeeze():  tensor([[267.5585, 430.1639],
#         [278.5849, 446.8398],
#         [289.2451, 460.1523],
#         [262.7099, 422.8423]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[302., 453.],
#         [326., 594.],
#         [485., 632.],
#         [231., 356.]])
# y_predicted.squeeze():  tensor([[285.5343, 460.6488],
#         [295.1119, 471.4245],
#         [254.4959, 410.7915],
#         [253.9061, 410.5386]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[241., 447.],
#         [430., 584.],
#         [204., 372.],
#         [300., 481.]])
# y_predicted.squeeze():  tensor([[261.0727, 422.7875],
#         [306.6853, 492.8437],
#         [275.7704, 444.3205],
#         [341.4810, 545.3740]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[248., 430.],
#         [342., 638.],
#         [344., 471.],
#         [436., 641.]])
# y_predicted.squeeze():  tensor([[325.7182, 527.9418],
#         [285.1031, 459.3609],
#         [266.2731, 429.6602],
#         [303.0580, 484.1382]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[262., 474.],
#         [151., 316.],
#         [200., 311.],
#         [410., 574.]])
# y_predicted.squeeze():  tensor([[284.7014, 460.8195],
#         [290.0227, 468.7475],
#         [294.6017, 477.1928],
#         [281.5974, 456.5890]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[172., 297.],
#         [400., 564.],
#         [196., 359.],
#         [448., 630.]])
# y_predicted.squeeze():  tensor([[209.7556, 381.4103],
#         [228.7938, 417.8782],
#         [190.4030, 364.8180],
#         [188.6539, 355.3724]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[210., 375.],
#         [219., 339.],
#         [149., 341.],
#         [170., 345.]])
# y_predicted.squeeze():  tensor([[167.0795, 323.4602],
#         [223.5001, 376.0674],
#         [236.8543, 394.1994],
#         [271.9771, 438.1237]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[210., 335.],
#         [336., 532.],
#         [318., 500.],
#         [389., 547.]])
# y_predicted.squeeze():  tensor([[400.2129, 623.2443],
#         [175.1107, 344.3476],
#         [295.0192, 471.7105],
#         [264.9886, 425.8586]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[378., 566.],
#         [259., 377.],
#         [354., 522.],
#         [414., 558.]])
# y_predicted.squeeze():  tensor([[231.4561, 410.6625],
#         [253.2177, 431.6555],
#         [268.4283, 437.7006],
#         [171.0617, 330.8312]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[243., 428.],
#         [310., 626.],
#         [377., 502.],
#         [195., 340.]])
# y_predicted.squeeze():  tensor([[195.7729, 357.6137],
#         [191.3962, 353.9424],
#         [292.0497, 465.6397],
#         [387.9125, 597.2298]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[249., 400.],
#         [141., 376.],
#         [451., 604.],
#         [341., 614.]])
# y_predicted.squeeze():  tensor([[281.2614, 449.0142],
#         [208.2308, 371.2521],
#         [251.8172, 409.9585],
#         [217.8514, 377.4371]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[332., 504.],
#         [240., 411.],
#         [334., 510.],
#         [283., 471.]])
# y_predicted.squeeze():  tensor([[306.5404, 472.1011],
#         [281.9430, 458.0611],
#         [203.3365, 372.0821],
#         [215.3608, 389.3891]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[374., 546.],
#         [351., 532.],
#         [148., 292.],
#         [232., 396.]])
# y_predicted.squeeze():  tensor([[431.5563, 637.4448],
#         [232.0555, 404.6339],
#         [422.0191, 616.3192],
#         [305.2107, 496.2299]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[529., 660.],
#         [162., 324.],
#         [493., 637.],
#         [262., 477.]])
# y_predicted.squeeze():  tensor([[321.9963, 523.3936],
#         [306.4268, 489.7601],
#         [306.2204, 494.6023],
#         [463.7794, 663.5296]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[148., 485.],
#         [245., 488.],
#         [307., 487.],
#         [395., 573.]])
# y_predicted.squeeze():  tensor([[340.4925, 562.7045],
#         [438.2621, 633.4973],
#         [359.0353, 551.6584],
#         [337.7681, 520.2286]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[227., 417.],
#         [458., 603.],
#         [323., 500.],
#         [290., 458.]])
# y_predicted.squeeze():  tensor([[300.2805, 477.3480],
#         [315.2870, 500.4269],
#         [428.3059, 618.2247],
#         [387.3579, 582.3647]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[231., 376.],
#         [281., 420.],
#         [407., 587.],
#         [306., 487.]])
# y_predicted.squeeze():  tensor([[276.2880, 454.9214],
#         [387.5833, 568.5081],
#         [373.7719, 558.1791],
#         [306.8374, 495.3841]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[227., 408.],
#         [354., 568.],
#         [311., 553.],
#         [149., 288.]])
# y_predicted.squeeze():  tensor([[342.3042, 506.6320],
#         [406.8670, 586.4507],
#         [399.0944, 584.1226],
#         [245.6758, 417.1498]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[367., 512.],
#         [493., 627.],
#         [455., 588.],
#         [220., 350.]])
# y_predicted.squeeze():  tensor([[369.4411, 543.6282],
#         [261.0081, 448.4603],
#         [262.5468, 418.4035],
#         [321.7297, 521.0548]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([
], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[335., 527.],
#         [332., 510.],
#         [144., 296.],
#         [281., 486.]])
# y_predicted.squeeze():  tensor([[313.8363, 523.5572],
#         [380.5220, 566.7662],
#         [299.4961, 490.0270],
#         [286.4589, 486.7042]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[221., 469.],
#         [350., 552.],
#         [242., 415.],
#         [174., 389.]])
# y_predicted.squeeze():  tensor([[260.0963, 434.8416],
#         [439.8978, 644.1761],
#         [391.7978, 589.5357],
#         [247.0421, 422.1021]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[144., 336.],
#         [414., 608.],
#         [419., 568.],
#         [173., 318.]])
# y_predicted.squeeze():  tensor([[243.9928, 403.7069],
#         [303.6426, 464.1162],
#         [335.6675, 504.9307],
#         [346.5331, 510.6674]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[287., 433.],
#         [316., 487.],
#         [503., 654.],
#         [505., 627.]])
# y_predicted.squeeze():  tensor([[358.6829, 522.6470],
#         [298.6222, 451.0446],
#         [236.0556, 403.5129],
#         [202.6466, 350.8878]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[394., 588.],
#         [396., 504.],
#         [252., 391.],
#         [182., 364.]])
# y_predicted.squeeze():  tensor([[199.9993, 352.7000],
#         [262.3747, 430.5756],
#         [311.1617, 465.3209],
#         [301.3903, 449.7776]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[222., 403.],
#         [301., 494.],
#         [445., 584.],
#         [435., 587.]])
# y_predicted.squeeze():  tensor([[226.3592, 385.9444],
#         [200.0693, 362.2868],
#         [200.2928, 360.1397]], grad_fn=<SqueezeBackward0>)
# y_batch.float():  tensor([[243., 449.],
#         [157., 331.],
#         [232., 333.]])
# Val loss: 4884.26171875, Val acc: 0.6880530714988708
#
# Tiempo total de entrenamiento: 48.0174 [s]

# %%
CNN1d = CNN1d_Model(dropout_p=0.5)
curves = train_model(
    CNN1d,
    train_ds,
    val_ds,
    epochs,
    criterion,
    batch_size,
    lr,
    use_gpu=False,
    data_augmentation=False,
    delta=5000*5000
)
show_curves(curves)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# y_pred.unsqueeze(0) tensor([[324.3769, 503.7905]])
# y.unsqueeze(0) tensor([[380, 564]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.7635, 437.6969]])
# y.unsqueeze(0) tensor([[273, 405]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[323.5629, 503.5442]])
# y.unsqueeze(0) tensor([[345, 536]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[264.6100, 418.8024]])
# y.unsqueeze(0) tensor([[199, 384]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[332.7955, 514.9066]])
# y.unsqueeze(0) tensor([[403, 607]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[341.4413, 528.9490]])
# y.unsqueeze(0) tensor([[446, 651]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.9825, 508.8872]])
# y.unsqueeze(0) tensor([[338, 496]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[340.2267, 525.9417]])
# y.unsqueeze(0) tensor([[505, 647]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.1191, 446.2554]])
# y.unsqueeze(0) tensor([[190, 398]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[295.0301, 460.7820]])
# y.unsqueeze(0) tensor([[279, 498]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.2737, 451.0528]])
# y.unsqueeze(0) tensor([[292, 497]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.7136, 496.4927]])
# y.unsqueeze(0) tensor([[473, 651]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[332.4258, 517.1237]])
# y.unsqueeze(0) tensor([[358, 466]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.2858, 482.7711]])
# y.unsqueeze(0) tensor([[365, 533]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[270.0333, 428.5935]])
# y.unsqueeze(0) tensor([[184, 373]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[268.5532, 425.3994]])
# y.unsqueeze(0) tensor([[180, 322]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[338.6121, 524.6364]])
# y.unsqueeze(0) tensor([[351, 563]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[263.8104, 415.4326]])
# y.unsqueeze(0) tensor([[150, 318]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[300.9212, 468.3192]])
# y.unsqueeze(0) tensor([[418, 586]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.3637, 458.2090]])
# y.unsqueeze(0) tensor([[323, 552]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.3955, 477.7915]])
# y.unsqueeze(0) tensor([[390, 571]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.3634, 445.2498]])
# y.unsqueeze(0) tensor([[318, 486]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.7251, 442.8705]])
# y.unsqueeze(0) tensor([[188, 434]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[334.6820, 519.7452]])
# y.unsqueeze(0) tensor([[335, 543]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.2138, 467.7628]])
# y.unsqueeze(0) tensor([[188, 335]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[355.5010, 550.6998]])
# y.unsqueeze(0) tensor([[449, 640]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.4942, 500.1557]])
# y.unsqueeze(0) tensor([[298, 540]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.3410, 498.5887]])
# y.unsqueeze(0) tensor([[376, 561]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.6732, 439.7130]])
# y.unsqueeze(0) tensor([[156, 294]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.9271, 438.1260]])
# y.unsqueeze(0) tensor([[263, 428]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.8222, 444.5460]])
# y.unsqueeze(0) tensor([[233, 361]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.3765, 501.3108]])
# y.unsqueeze(0) tensor([[311, 447]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[270.7078, 427.5835]])
# y.unsqueeze(0) tensor([[236, 394]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[340.9588, 527.6749]])
# y.unsqueeze(0) tensor([[386, 651]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.6928, 451.3641]])
# y.unsqueeze(0) tensor([[436, 561]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.8360, 437.4928]])
# y.unsqueeze(0) tensor([[326, 457]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.1407, 456.4994]])
# y.unsqueeze(0) tensor([[279, 440]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[332.5346, 515.8779]])
# y.unsqueeze(0) tensor([[380, 652]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[340.7405, 529.1228]])
# y.unsqueeze(0) tensor([[430, 623]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.6880, 431.1989]])
# y.unsqueeze(0) tensor([[225, 372]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.9655, 463.5944]])
# y.unsqueeze(0) tensor([[253, 467]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.9930, 421.4924]])
# y.unsqueeze(0) tensor([[244, 429]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[330.8188, 511.0263]])
# y.unsqueeze(0) tensor([[478, 659]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.0433, 470.8914]])
# y.unsqueeze(0) tensor([[402, 554]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.6487, 490.2717]])
# y.unsqueeze(0) tensor([[403, 598]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[323.0820, 506.6972]])
# y.unsqueeze(0) tensor([[281, 507]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[316.7744, 496.1435]])
# y.unsqueeze(0) tensor([[237, 530]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.3932, 436.7744]])
# y.unsqueeze(0) tensor([[288, 456]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.4342, 505.0936]])
# y.unsqueeze(0) tensor([[391, 546]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.1831, 443.2056]])
# y.unsqueeze(0) tensor([[186, 424]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[291.2864, 454.0708]])
# y.unsqueeze(0) tensor([[377, 589]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[279.0733, 442.4779]])
# y.unsqueeze(0) tensor([[236, 367]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.0298, 482.4699]])
# y.unsqueeze(0) tensor([[321, 580]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.2076, 466.7255]])
# y.unsqueeze(0) tensor([[223, 364]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.3641, 438.3565]])
# y.unsqueeze(0) tensor([[185, 323]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.8717, 443.9241]])
# y.unsqueeze(0) tensor([[320, 464]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.1982, 472.3348]])
# y.unsqueeze(0) tensor([[386, 551]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.0177, 437.8931]])
# y.unsqueeze(0) tensor([[312, 434]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[380.0935, 588.3129]])
# y.unsqueeze(0) tensor([[389, 624]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.5401, 500.0931]])
# y.unsqueeze(0) tensor([[306, 495]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[343.3035, 531.0599]])
# y.unsqueeze(0) tensor([[468, 623]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[317.3501, 494.1864]])
# y.unsqueeze(0) tensor([[357, 606]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.9682, 455.0291]])
# y.unsqueeze(0) tensor([[193, 435]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.9769, 476.0948]])
# y.unsqueeze(0) tensor([[180, 503]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.3599, 490.0552]])
# y.unsqueeze(0) tensor([[375, 613]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.8425, 445.1248]])
# y.unsqueeze(0) tensor([[219, 384]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.1039, 443.6348]])
# y.unsqueeze(0) tensor([[236, 365]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.7559, 432.9938]])
# y.unsqueeze(0) tensor([[316, 480]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[329.0857, 509.2614]])
# y.unsqueeze(0) tensor([[440, 598]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.4391, 431.6900]])
# y.unsqueeze(0) tensor([[232, 407]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.0001, 494.7440]])
# y.unsqueeze(0) tensor([[383, 628]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[316.2634, 491.3903]])
# y.unsqueeze(0) tensor([[345, 536]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.9960, 493.4142]])
# y.unsqueeze(0) tensor([[243, 506]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.6409, 420.7923]])
# y.unsqueeze(0) tensor([[195, 344]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[330.3716, 513.2152]])
# y.unsqueeze(0) tensor([[365, 577]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.0829, 451.7685]])
# y.unsqueeze(0) tensor([[194, 362]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.7999, 438.4525]])
# y.unsqueeze(0) tensor([[253, 424]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.5733, 435.3025]])
# y.unsqueeze(0) tensor([[211, 396]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.8607, 479.8026]])
# y.unsqueeze(0) tensor([[391, 528]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.6326, 428.1865]])
# y.unsqueeze(0) tensor([[230, 412]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.9041, 458.0493]])
# y.unsqueeze(0) tensor([[429, 546]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.8184, 424.9552]])
# y.unsqueeze(0) tensor([[158, 329]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.3921, 457.8433]])
# y.unsqueeze(0) tensor([[165, 444]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.5867, 443.9508]])
# y.unsqueeze(0) tensor([[319, 484]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[354.3242, 547.2726]])
# y.unsqueeze(0) tensor([[423, 624]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.6359, 480.5214]])
# y.unsqueeze(0) tensor([[195, 393]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.8401, 471.1853]])
# y.unsqueeze(0) tensor([[190, 352]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.8261, 490.5729]])
# y.unsqueeze(0) tensor([[416, 520]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.1240, 446.8405]])
# y.unsqueeze(0) tensor([[296, 435]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[306.0905, 477.9349]])
# y.unsqueeze(0) tensor([[305, 493]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.7011, 482.3003]])
# y.unsqueeze(0) tensor([[424, 585]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.2724, 465.0244]])
# y.unsqueeze(0) tensor([[286, 451]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[292.5862, 459.9412]])
# y.unsqueeze(0) tensor([[222, 421]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[308.6907, 483.5537]])
# y.unsqueeze(0) tensor([[277, 482]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[333.8022, 517.0721]])
# y.unsqueeze(0) tensor([[470, 625]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.4442, 472.9670]])
# y.unsqueeze(0) tensor([[378, 512]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.6288, 468.5760]])
# y.unsqueeze(0) tensor([[196, 405]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.6218, 437.0714]])
# y.unsqueeze(0) tensor([[234, 405]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.8092, 447.2089]])
# y.unsqueeze(0) tensor([[168, 346]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.7108, 454.5792]])
# y.unsqueeze(0) tensor([[235, 430]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[308.7015, 479.1143]])
# y.unsqueeze(0) tensor([[530, 647]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.3533, 445.7599]])
# y.unsqueeze(0) tensor([[316, 500]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[259.2776, 408.4885]])
# y.unsqueeze(0) tensor([[152, 311]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[279.2574, 439.7410]])
# y.unsqueeze(0) tensor([[218, 382]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.2513, 430.7478]])
# y.unsqueeze(0) tensor([[197, 379]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.3217, 470.4621]])
# y.unsqueeze(0) tensor([[448, 583]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[299.7733, 466.3540]])
# y.unsqueeze(0) tensor([[415, 560]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.9494, 456.8377]])
# y.unsqueeze(0) tensor([[249, 438]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.0713, 488.0462]])
# y.unsqueeze(0) tensor([[502, 650]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.9953, 482.4730]])
# y.unsqueeze(0) tensor([[455, 600]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.5737, 453.3873]])
# y.unsqueeze(0) tensor([[199, 320]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.4996, 441.3895]])
# y.unsqueeze(0) tensor([[306, 450]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[350.0697, 541.8712]])
# y.unsqueeze(0) tensor([[469, 617]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[341.9609, 528.2084]])
# y.unsqueeze(0) tensor([[464, 625]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.4022, 481.0369]])
# y.unsqueeze(0) tensor([[356, 564]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.6201, 437.3177]])
# y.unsqueeze(0) tensor([[251, 382]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.5289, 434.5219]])
# y.unsqueeze(0) tensor([[160, 352]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.2607, 475.6935]])
# y.unsqueeze(0) tensor([[514, 652]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.0528, 457.7338]])
# y.unsqueeze(0) tensor([[353, 528]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.5590, 480.6937]])
# y.unsqueeze(0) tensor([[396, 580]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[301.9768, 469.8293]])
# y.unsqueeze(0) tensor([[437, 615]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.5135, 490.4294]])
# y.unsqueeze(0) tensor([[503, 617]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.4669, 469.5438]])
# y.unsqueeze(0) tensor([[258, 436]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.5945, 497.0430]])
# y.unsqueeze(0) tensor([[369, 518]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.8394, 488.7984]])
# y.unsqueeze(0) tensor([[370, 535]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.4546, 474.9691]])
# y.unsqueeze(0) tensor([[340, 539]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[339.5690, 526.7402]])
# y.unsqueeze(0) tensor([[430, 628]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.9873, 497.1486]])
# y.unsqueeze(0) tensor([[424, 579]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.2125, 420.9978]])
# y.unsqueeze(0) tensor([[193, 351]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.7225, 436.3402]])
# y.unsqueeze(0) tensor([[251, 433]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.6652, 481.1571]])
# y.unsqueeze(0) tensor([[463, 648]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.2114, 495.8610]])
# y.unsqueeze(0) tensor([[385, 553]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[328.9673, 510.2234]])
# y.unsqueeze(0) tensor([[377, 591]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.4725, 481.8269]])
# y.unsqueeze(0) tensor([[406, 550]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.4216, 483.0219]])
# y.unsqueeze(0) tensor([[355, 523]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.7711, 499.4156]])
# y.unsqueeze(0) tensor([[330, 609]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.5913, 458.2173]])
# y.unsqueeze(0) tensor([[356, 514]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.8581, 422.4693]])
# y.unsqueeze(0) tensor([[207, 345]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.7626, 505.5588]])
# y.unsqueeze(0) tensor([[475, 653]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.3170, 429.9171]])
# y.unsqueeze(0) tensor([[208, 367]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.2896, 432.0077]])
# y.unsqueeze(0) tensor([[216, 347]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.8195, 484.3323]])
# y.unsqueeze(0) tensor([[347, 518]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.0984, 446.5468]])
# y.unsqueeze(0) tensor([[164, 342]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.0437, 459.2546]])
# y.unsqueeze(0) tensor([[148, 319]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[324.2961, 502.8652]])
# y.unsqueeze(0) tensor([[433, 601]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.5721, 479.3285]])
# y.unsqueeze(0) tensor([[249, 437]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[335.0591, 520.2472]])
# y.unsqueeze(0) tensor([[490, 657]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.4367, 442.6375]])
# y.unsqueeze(0) tensor([[180, 368]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.6602, 426.7682]])
# y.unsqueeze(0) tensor([[150, 308]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[306.8882, 477.3421]])
# y.unsqueeze(0) tensor([[346, 542]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[264.2734, 417.5558]])
# y.unsqueeze(0) tensor([[231, 369]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.0064, 444.8829]])
# y.unsqueeze(0) tensor([[144, 335]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[268.6769, 421.7535]])
# y.unsqueeze(0) tensor([[173, 332]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.8513, 426.0445]])
# y.unsqueeze(0) tensor([[196, 330]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[339.5992, 526.3662]])
# y.unsqueeze(0) tensor([[430, 619]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.9095, 455.2560]])
# y.unsqueeze(0) tensor([[229, 433]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.8580, 473.7742]])
# y.unsqueeze(0) tensor([[307, 580]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.8626, 507.7328]])
# y.unsqueeze(0) tensor([[399, 588]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.6865, 506.9778]])
# y.unsqueeze(0) tensor([[324, 590]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.7303, 440.9876]])
# y.unsqueeze(0) tensor([[334, 465]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.7678, 484.3933]])
# y.unsqueeze(0) tensor([[166, 387]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.6295, 452.0061]])
# y.unsqueeze(0) tensor([[204, 457]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.1306, 506.4984]])
# y.unsqueeze(0) tensor([[362, 584]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.5382, 433.6354]])
# y.unsqueeze(0) tensor([[168, 373]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.0583, 443.9122]])
# y.unsqueeze(0) tensor([[253, 454]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.7848, 438.5098]])
# y.unsqueeze(0) tensor([[256, 414]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.7629, 458.9164]])
# y.unsqueeze(0) tensor([[409, 567]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[286.1325, 447.4901]])
# y.unsqueeze(0) tensor([[359, 507]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[316.2757, 491.2747]])
# y.unsqueeze(0) tensor([[387, 545]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.7334, 497.5498]])
# y.unsqueeze(0) tensor([[285, 571]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[265.1463, 418.2908]])
# y.unsqueeze(0) tensor([[150, 331]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.2682, 447.2953]])
# y.unsqueeze(0) tensor([[287, 459]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.4024, 482.7446]])
# y.unsqueeze(0) tensor([[424, 613]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[324.9796, 502.5886]])
# y.unsqueeze(0) tensor([[433, 617]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.8030, 487.7009]])
# y.unsqueeze(0) tensor([[463, 611]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.6663, 433.8300]])
# y.unsqueeze(0) tensor([[252, 377]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[305.5224, 475.8426]])
# y.unsqueeze(0) tensor([[404, 508]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[300.4533, 470.8933]])
# y.unsqueeze(0) tensor([[277, 495]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.3764, 461.5638]])
# y.unsqueeze(0) tensor([[383, 558]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.3012, 451.0572]])
# y.unsqueeze(0) tensor([[325, 483]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.4178, 496.9416]])
# y.unsqueeze(0) tensor([[405, 604]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.1420, 442.1837]])
# y.unsqueeze(0) tensor([[291, 469]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.8011, 489.1193]])
# y.unsqueeze(0) tensor([[477, 604]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.3762, 425.7631]])
# y.unsqueeze(0) tensor([[206, 357]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.3723, 438.3801]])
# y.unsqueeze(0) tensor([[332, 470]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.4849, 472.6552]])
# y.unsqueeze(0) tensor([[497, 658]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.0377, 420.1090]])
# y.unsqueeze(0) tensor([[158, 302]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.9665, 456.5684]])
# y.unsqueeze(0) tensor([[332, 479]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.4235, 506.9694]])
# y.unsqueeze(0) tensor([[303, 541]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.9505, 448.3671]])
# y.unsqueeze(0) tensor([[330, 480]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.0616, 465.6164]])
# y.unsqueeze(0) tensor([[232, 413]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.7296, 486.7254]])
# y.unsqueeze(0) tensor([[339, 504]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[332.7000, 514.3055]])
# y.unsqueeze(0) tensor([[485, 649]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.9804, 445.1544]])
# y.unsqueeze(0) tensor([[284, 409]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[322.1746, 499.8625]])
# y.unsqueeze(0) tensor([[396, 541]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.2033, 439.4648]])
# y.unsqueeze(0) tensor([[229, 401]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.2040, 444.3190]])
# y.unsqueeze(0) tensor([[234, 378]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[313.1317, 489.7137]])
# y.unsqueeze(0) tensor([[398, 513]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.3513, 479.5376]])
# y.unsqueeze(0) tensor([[298, 517]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.3828, 436.6910]])
# y.unsqueeze(0) tensor([[227, 415]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.6791, 463.1662]])
# y.unsqueeze(0) tensor([[473, 594]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[306.0896, 479.2512]])
# y.unsqueeze(0) tensor([[206, 454]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.0782, 452.0801]])
# y.unsqueeze(0) tensor([[219, 465]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.9776, 429.1768]])
# y.unsqueeze(0) tensor([[175, 343]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[301.0788, 469.7928]])
# y.unsqueeze(0) tensor([[412, 557]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.0004, 457.6172]])
# y.unsqueeze(0) tensor([[318, 469]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.0388, 485.8881]])
# y.unsqueeze(0) tensor([[393, 568]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.3010, 445.6677]])
# y.unsqueeze(0) tensor([[323, 481]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[292.4098, 459.4631]])
# y.unsqueeze(0) tensor([[202, 380]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[333.1357, 517.0629]])
# y.unsqueeze(0) tensor([[436, 567]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.7855, 473.3290]])
# y.unsqueeze(0) tensor([[362, 514]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.1401, 438.5223]])
# y.unsqueeze(0) tensor([[295, 449]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.3622, 461.4584]])
# y.unsqueeze(0) tensor([[385, 489]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[344.6039, 531.8337]])
# y.unsqueeze(0) tensor([[423, 568]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.6986, 430.6610]])
# y.unsqueeze(0) tensor([[256, 421]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.2830, 432.9742]])
# y.unsqueeze(0) tensor([[251, 381]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.1772, 427.2917]])
# y.unsqueeze(0) tensor([[187, 369]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.9131, 481.2239]])
# y.unsqueeze(0) tensor([[497, 611]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.7785, 442.1946]])
# y.unsqueeze(0) tensor([[163, 357]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.0010, 435.7107]])
# y.unsqueeze(0) tensor([[341, 472]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.1035, 439.4186]])
# y.unsqueeze(0) tensor([[265, 365]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[322.6795, 499.5487]])
# y.unsqueeze(0) tensor([[430, 577]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.9673, 454.6527]])
# y.unsqueeze(0) tensor([[285, 402]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.1913, 497.2302]])
# y.unsqueeze(0) tensor([[371, 532]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.8158, 471.6533]])
# y.unsqueeze(0) tensor([[210, 409]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.8220, 450.9444]])
# y.unsqueeze(0) tensor([[267, 399]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[344.1521, 533.0168]])
# y.unsqueeze(0) tensor([[460, 611]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.0947, 463.8086]])
# y.unsqueeze(0) tensor([[379, 511]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.7299, 493.7901]])
# y.unsqueeze(0) tensor([[425, 600]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[273.7489, 432.0560]])
# y.unsqueeze(0) tensor([[157, 359]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.9897, 442.1698]])
# y.unsqueeze(0) tensor([[293, 467]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[266.3185, 417.9938]])
# y.unsqueeze(0) tensor([[303, 435]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[300.7856, 469.4507]])
# y.unsqueeze(0) tensor([[325, 479]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.9515, 446.6131]])
# y.unsqueeze(0) tensor([[279, 460]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.3971, 487.4298]])
# y.unsqueeze(0) tensor([[351, 515]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.7063, 438.4865]])
# y.unsqueeze(0) tensor([[161, 470]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.6245, 487.8856]])
# y.unsqueeze(0) tensor([[404, 606]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[308.9333, 478.7718]])
# y.unsqueeze(0) tensor([[485, 616]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.5642, 483.8015]])
# y.unsqueeze(0) tensor([[335, 516]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[295.3219, 460.1859]])
# y.unsqueeze(0) tensor([[388, 566]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[324.2426, 503.4904]])
# y.unsqueeze(0) tensor([[314, 556]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.5746, 450.2923]])
# y.unsqueeze(0) tensor([[333, 498]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[316.0815, 492.1469]])
# y.unsqueeze(0) tensor([[362, 584]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[322.5753, 499.3123]])
# y.unsqueeze(0) tensor([[449, 598]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.9871, 493.2318]])
# y.unsqueeze(0) tensor([[222, 492]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.3615, 470.0664]])
# y.unsqueeze(0) tensor([[393, 551]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.9987, 456.5410]])
# y.unsqueeze(0) tensor([[141, 332]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.3593, 471.3531]])
# y.unsqueeze(0) tensor([[242, 407]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.1871, 451.3819]])
# y.unsqueeze(0) tensor([[178, 326]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[270.1970, 423.5491]])
# y.unsqueeze(0) tensor([[246, 404]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[297.3673, 463.0502]])
# y.unsqueeze(0) tensor([[363, 514]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.1124, 429.3022]])
# y.unsqueeze(0) tensor([[160, 351]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[270.5175, 425.6530]])
# y.unsqueeze(0) tensor([[194, 369]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[295.2591, 460.9230]])
# y.unsqueeze(0) tensor([[362, 501]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.9669, 422.2603]])
# y.unsqueeze(0) tensor([[274, 402]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[300.1281, 473.6080]])
# y.unsqueeze(0) tensor([[212, 416]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[327.2279, 507.8904]])
# y.unsqueeze(0) tensor([[363, 564]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.2855, 427.4624]])
# y.unsqueeze(0) tensor([[142, 307]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.4991, 497.3026]])
# y.unsqueeze(0) tensor([[339, 591]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[328.6300, 508.8565]])
# y.unsqueeze(0) tensor([[470, 648]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.4208, 479.2960]])
# y.unsqueeze(0) tensor([[459, 600]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.9188, 451.6614]])
# y.unsqueeze(0) tensor([[154, 396]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.7470, 484.1926]])
# y.unsqueeze(0) tensor([[436, 575]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[314.0670, 485.5742]])
# y.unsqueeze(0) tensor([[486, 601]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.9041, 422.2616]])
# y.unsqueeze(0) tensor([[296, 417]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[327.7637, 506.4458]])
# y.unsqueeze(0) tensor([[516, 657]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.6854, 428.6867]])
# y.unsqueeze(0) tensor([[196, 357]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[329.2172, 512.2578]])
# y.unsqueeze(0) tensor([[320, 506]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.3034, 456.9765]])
# y.unsqueeze(0) tensor([[278, 463]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[295.8398, 461.6569]])
# y.unsqueeze(0) tensor([[360, 538]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[273.8128, 432.3411]])
# y.unsqueeze(0) tensor([[185, 407]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[333.2488, 516.0565]])
# y.unsqueeze(0) tensor([[353, 562]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.0679, 505.4320]])
# y.unsqueeze(0) tensor([[396, 554]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[317.4935, 492.1779]])
# y.unsqueeze(0) tensor([[484, 652]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[363.0359, 562.8473]])
# y.unsqueeze(0) tensor([[368, 564]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.8369, 501.9415]])
# y.unsqueeze(0) tensor([[240, 456]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.2044, 444.0389]])
# y.unsqueeze(0) tensor([[298, 452]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[324.2934, 503.4855]])
# y.unsqueeze(0) tensor([[403, 601]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.8170, 499.6352]])
# y.unsqueeze(0) tensor([[392, 593]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.4846, 431.4742]])
# y.unsqueeze(0) tensor([[202, 374]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[308.8987, 483.2490]])
# y.unsqueeze(0) tensor([[396, 587]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.1014, 428.5511]])
# y.unsqueeze(0) tensor([[178, 339]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.2596, 428.6567]])
# y.unsqueeze(0) tensor([[144, 312]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.4695, 443.4223]])
# y.unsqueeze(0) tensor([[295, 448]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.4696, 497.9922]])
# y.unsqueeze(0) tensor([[473, 624]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.1736, 440.7048]])
# y.unsqueeze(0) tensor([[177, 365]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[288.4984, 453.4362]])
# y.unsqueeze(0) tensor([[269, 470]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.3606, 431.5825]])
# y.unsqueeze(0) tensor([[180, 375]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.9159, 436.1635]])
# y.unsqueeze(0) tensor([[221, 362]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[336.4668, 521.3805]])
# y.unsqueeze(0) tensor([[467, 632]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[328.3230, 509.6230]])
# y.unsqueeze(0) tensor([[417, 586]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[332.3215, 515.8340]])
# y.unsqueeze(0) tensor([[434, 541]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.9994, 483.6104]])
# y.unsqueeze(0) tensor([[401, 549]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.9691, 439.0473]])
# y.unsqueeze(0) tensor([[192, 457]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.4258, 426.7222]])
# y.unsqueeze(0) tensor([[304, 415]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.4646, 455.3310]])
# y.unsqueeze(0) tensor([[255, 440]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.9621, 476.1675]])
# y.unsqueeze(0) tensor([[361, 543]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.8591, 436.0028]])
# y.unsqueeze(0) tensor([[191, 355]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.1247, 460.2302]])
# y.unsqueeze(0) tensor([[317, 471]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.1560, 435.0633]])
# y.unsqueeze(0) tensor([[147, 328]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.7717, 473.3601]])
# y.unsqueeze(0) tensor([[456, 583]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.6794, 467.5963]])
# y.unsqueeze(0) tensor([[163, 321]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.6778, 433.0562]])
# y.unsqueeze(0) tensor([[257, 439]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.3443, 445.6642]])
# y.unsqueeze(0) tensor([[286, 454]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[299.8854, 466.6847]])
# y.unsqueeze(0) tensor([[413, 568]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.6381, 483.6745]])
# y.unsqueeze(0) tensor([[428, 600]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.0983, 502.6179]])
# y.unsqueeze(0) tensor([[510, 651]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[305.4770, 475.7325]])
# y.unsqueeze(0) tensor([[356, 563]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.7288, 473.4352]])
# y.unsqueeze(0) tensor([[210, 502]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[266.6631, 418.8621]])
# y.unsqueeze(0) tensor([[242, 343]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.5434, 504.9694]])
# y.unsqueeze(0) tensor([[443, 608]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.7107, 427.8151]])
# y.unsqueeze(0) tensor([[149, 310]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.7731, 446.6668]])
# y.unsqueeze(0) tensor([[192, 364]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.8511, 433.9568]])
# y.unsqueeze(0) tensor([[266, 377]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[263.8083, 415.7503]])
# y.unsqueeze(0) tensor([[213, 344]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[264.8552, 415.0866]])
# y.unsqueeze(0) tensor([[152, 273]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.7909, 422.2897]])
# y.unsqueeze(0) tensor([[207, 342]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.2753, 457.2704]])
# y.unsqueeze(0) tensor([[424, 545]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.5543, 427.6297]])
# y.unsqueeze(0) tensor([[298, 453]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.8015, 429.3150]])
# y.unsqueeze(0) tensor([[421, 532]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.4285, 428.1009]])
# y.unsqueeze(0) tensor([[299, 443]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.4767, 419.7569]])
# y.unsqueeze(0) tensor([[190, 325]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[301.9145, 470.1798]])
# y.unsqueeze(0) tensor([[434, 572]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[263.1711, 414.8430]])
# y.unsqueeze(0) tensor([[277, 419]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.9714, 442.4551]])
# y.unsqueeze(0) tensor([[215, 390]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[262.8996, 413.4977]])
# y.unsqueeze(0) tensor([[181, 359]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.4816, 472.1812]])
# y.unsqueeze(0) tensor([[462, 623]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.7580, 448.6270]])
# y.unsqueeze(0) tensor([[342, 490]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[273.2348, 427.3054]])
# y.unsqueeze(0) tensor([[274, 411]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.0121, 456.5666]])
# y.unsqueeze(0) tensor([[367, 549]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.6717, 441.0615]])
# y.unsqueeze(0) tensor([[225, 363]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.3183, 458.8231]])
# y.unsqueeze(0) tensor([[500, 638]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.0657, 430.3024]])
# y.unsqueeze(0) tensor([[353, 474]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.0597, 461.9868]])
# y.unsqueeze(0) tensor([[357, 491]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.1947, 444.4774]])
# y.unsqueeze(0) tensor([[316, 463]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.1374, 446.8285]])
# y.unsqueeze(0) tensor([[448, 552]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[310.2535, 480.5644]])
# y.unsqueeze(0) tensor([[482, 640]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.4968, 445.8378]])
# y.unsqueeze(0) tensor([[295, 446]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.3579, 452.8986]])
# y.unsqueeze(0) tensor([[468, 619]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[338.1387, 523.1663]])
# y.unsqueeze(0) tensor([[393, 614]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.0771, 440.4329]])
# y.unsqueeze(0) tensor([[195, 316]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.7736, 482.7555]])
# y.unsqueeze(0) tensor([[491, 609]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[335.9816, 520.2448]])
# y.unsqueeze(0) tensor([[398, 569]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.3681, 433.4831]])
# y.unsqueeze(0) tensor([[251, 385]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[320.3194, 497.5455]])
# y.unsqueeze(0) tensor([[295, 493]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[326.2201, 506.0027]])
# y.unsqueeze(0) tensor([[414, 572]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.9237, 466.4549]])
# y.unsqueeze(0) tensor([[351, 509]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.7574, 470.5633]])
# y.unsqueeze(0) tensor([[385, 553]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[313.1508, 485.4981]])
# y.unsqueeze(0) tensor([[434, 639]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.8959, 443.6617]])
# y.unsqueeze(0) tensor([[276, 423]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.3703, 447.0957]])
# y.unsqueeze(0) tensor([[285, 420]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.0880, 437.5220]])
# y.unsqueeze(0) tensor([[205, 447]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.5474, 427.9566]])
# y.unsqueeze(0) tensor([[317, 468]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.5059, 483.8967]])
# y.unsqueeze(0) tensor([[365, 557]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[303.6824, 472.1790]])
# y.unsqueeze(0) tensor([[349, 568]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[330.3858, 510.0408]])
# y.unsqueeze(0) tensor([[489, 654]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.6248, 445.3719]])
# y.unsqueeze(0) tensor([[228, 383]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[292.4958, 457.1913]])
# y.unsqueeze(0) tensor([[294, 492]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[338.4232, 522.4647]])
# y.unsqueeze(0) tensor([[476, 647]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[327.0455, 509.5712]])
# y.unsqueeze(0) tensor([[321, 553]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[305.4705, 475.6007]])
# y.unsqueeze(0) tensor([[352, 520]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.6990, 442.1945]])
# y.unsqueeze(0) tensor([[268, 413]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.4240, 453.6136]])
# y.unsqueeze(0) tensor([[313, 494]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[305.5873, 474.7510]])
# y.unsqueeze(0) tensor([[412, 577]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.7227, 481.1636]])
# y.unsqueeze(0) tensor([[422, 574]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.7913, 449.0321]])
# y.unsqueeze(0) tensor([[362, 520]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.0192, 476.3840]])
# y.unsqueeze(0) tensor([[458, 609]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.8976, 503.7910]])
# y.unsqueeze(0) tensor([[441, 653]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.2031, 453.3103]])
# y.unsqueeze(0) tensor([[332, 470]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.7025, 471.3337]])
# y.unsqueeze(0) tensor([[391, 556]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[323.1058, 501.7854]])
# y.unsqueeze(0) tensor([[330, 524]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[308.0222, 480.9243]])
# y.unsqueeze(0) tensor([[359, 526]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[272.0606, 427.0565]])
# y.unsqueeze(0) tensor([[218, 426]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.4181, 485.2849]])
# y.unsqueeze(0) tensor([[360, 605]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.7511, 494.6098]])
# y.unsqueeze(0) tensor([[389, 597]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[341.6592, 529.4869]])
# y.unsqueeze(0) tensor([[388, 630]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.0110, 497.7718]])
# y.unsqueeze(0) tensor([[458, 592]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.0360, 439.5194]])
# y.unsqueeze(0) tensor([[168, 346]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[268.3256, 422.8091]])
# y.unsqueeze(0) tensor([[263, 384]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.1717, 437.0537]])
# y.unsqueeze(0) tensor([[247, 422]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.3708, 436.0918]])
# y.unsqueeze(0) tensor([[206, 371]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.4917, 478.3746]])
# y.unsqueeze(0) tensor([[421, 585]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.4641, 432.6651]])
# y.unsqueeze(0) tensor([[190, 405]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[313.6505, 487.3495]])
# y.unsqueeze(0) tensor([[418, 552]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.2796, 446.2523]])
# y.unsqueeze(0) tensor([[199, 380]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[335.8698, 521.9109]])
# y.unsqueeze(0) tensor([[437, 629]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.1009, 496.5215]])
# y.unsqueeze(0) tensor([[395, 560]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[270.3822, 427.4204]])
# y.unsqueeze(0) tensor([[145, 319]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.0916, 438.9260]])
# y.unsqueeze(0) tensor([[144, 339]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[338.0880, 522.3673]])
# y.unsqueeze(0) tensor([[434, 638]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[271.2285, 425.7473]])
# y.unsqueeze(0) tensor([[149, 294]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[304.7361, 474.5072]])
# y.unsqueeze(0) tensor([[344, 515]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[309.1866, 484.3079]])
# y.unsqueeze(0) tensor([[232, 421]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[329.6054, 510.3712]])
# y.unsqueeze(0) tensor([[431, 579]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.7332, 495.8103]])
# y.unsqueeze(0) tensor([[436, 547]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.6254, 474.0103]])
# y.unsqueeze(0) tensor([[222, 467]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.7830, 509.3556]])
# y.unsqueeze(0) tensor([[277, 445]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[273.9145, 431.6269]])
# y.unsqueeze(0) tensor([[216, 438]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.1453, 449.7378]])
# y.unsqueeze(0) tensor([[282, 488]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[358.1615, 554.1323]])
# y.unsqueeze(0) tensor([[457, 618]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.8291, 484.2139]])
# y.unsqueeze(0) tensor([[366, 498]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[287.4446, 455.3355]])
# y.unsqueeze(0) tensor([[151, 353]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[298.7444, 468.3348]])
# y.unsqueeze(0) tensor([[298, 476]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[306.3200, 476.4972]])
# y.unsqueeze(0) tensor([[498, 622]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.0418, 445.4698]])
# y.unsqueeze(0) tensor([[159, 373]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.4076, 446.2423]])
# y.unsqueeze(0) tensor([[318, 492]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.5287, 445.8829]])
# y.unsqueeze(0) tensor([[239, 374]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.7089, 436.0152]])
# y.unsqueeze(0) tensor([[206, 398]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[333.4630, 516.0815]])
# y.unsqueeze(0) tensor([[477, 648]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[284.1447, 448.0179]])
# y.unsqueeze(0) tensor([[148, 346]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[306.2974, 477.5879]])
# y.unsqueeze(0) tensor([[449, 631]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.9819, 446.1755]])
# y.unsqueeze(0) tensor([[199, 363]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.2570, 469.5781]])
# y.unsqueeze(0) tensor([[507, 621]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[291.8068, 454.6008]])
# y.unsqueeze(0) tensor([[412, 550]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[291.1559, 455.2297]])
# y.unsqueeze(0) tensor([[346, 518]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[347.9186, 538.1774]])
# y.unsqueeze(0) tensor([[414, 566]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.8264, 463.2346]])
# y.unsqueeze(0) tensor([[244, 429]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[286.7666, 451.3492]])
# y.unsqueeze(0) tensor([[159, 381]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[340.1143, 528.1843]])
# y.unsqueeze(0) tensor([[366, 554]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[299.0474, 468.5457]])
# y.unsqueeze(0) tensor([[316, 464]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[285.8181, 453.0178]])
# y.unsqueeze(0) tensor([[189, 377]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[281.5498, 442.8038]])
# y.unsqueeze(0) tensor([[277, 455]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.0735, 476.7162]])
# y.unsqueeze(0) tensor([[382, 614]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[342.5202, 529.9297]])
# y.unsqueeze(0) tensor([[462, 660]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[266.5306, 420.4122]])
# y.unsqueeze(0) tensor([[205, 380]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.5969, 497.8350]])
# y.unsqueeze(0) tensor([[370, 589]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[292.1008, 456.2865]])
# y.unsqueeze(0) tensor([[277, 512]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[261.3454, 413.2627]])
# y.unsqueeze(0) tensor([[158, 309]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[315.5251, 489.4844]])
# y.unsqueeze(0) tensor([[465, 622]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[276.7870, 434.9456]])
# y.unsqueeze(0) tensor([[279, 451]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.4857, 471.9494]])
# y.unsqueeze(0) tensor([[353, 542]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.9771, 453.4541]])
# y.unsqueeze(0) tensor([[385, 512]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.2377, 453.0938]])
# y.unsqueeze(0) tensor([[317, 454]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[289.3324, 457.4772]])
# y.unsqueeze(0) tensor([[263, 383]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.7281, 477.5323]])
# y.unsqueeze(0) tensor([[486, 621]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[275.1237, 436.3042]])
# y.unsqueeze(0) tensor([[155, 324]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.2706, 435.3214]])
# y.unsqueeze(0) tensor([[353, 481]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[292.2020, 456.7098]])
# y.unsqueeze(0) tensor([[327, 485]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[323.8642, 503.9643]])
# y.unsqueeze(0) tensor([[378, 492]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[318.6021, 496.8313]])
# y.unsqueeze(0) tensor([[409, 537]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[301.4723, 469.0547]])
# y.unsqueeze(0) tensor([[326, 518]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.7853, 487.0510]])
# y.unsqueeze(0) tensor([[339, 524]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[325.4378, 504.3213]])
# y.unsqueeze(0) tensor([[418, 559]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[324.4034, 502.4474]])
# y.unsqueeze(0) tensor([[429, 577]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[316.7773, 491.7250]])
# y.unsqueeze(0) tensor([[391, 575]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[329.5019, 509.1323]])
# y.unsqueeze(0) tensor([[475, 653]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[311.0992, 487.3724]])
# y.unsqueeze(0) tensor([[282, 470]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[290.8860, 458.7557]])
# y.unsqueeze(0) tensor([[244, 412]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[282.5229, 441.7354]])
# y.unsqueeze(0) tensor([[388, 539]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.7950, 470.3612]])
# y.unsqueeze(0) tensor([[371, 556]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[302.1566, 472.3259]])
# y.unsqueeze(0) tensor([[318, 532]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.0839, 463.3833]])
# y.unsqueeze(0) tensor([[244, 486]], dtype=torch.int32)
# ...
# y_pred.unsqueeze(0) tensor([[368.1233, 535.1435]])
# y.unsqueeze(0) tensor([[383, 531]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[312.4917, 462.4557]])
# y.unsqueeze(0) tensor([[387, 494]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[407.0695, 579.0323]])
# y.unsqueeze(0) tensor([[364, 583]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[200.7244, 389.6494]])
# y.unsqueeze(0) tensor([[157, 372]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[350.4836, 537.0522]])
# y.unsqueeze(0) tensor([[282, 551]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[429.7096, 603.9605]])
# y.unsqueeze(0) tensor([[342, 564]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[283.8203, 449.8257]])
# y.unsqueeze(0) tensor([[314, 448]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[406.3414, 588.5380]])
# y.unsqueeze(0) tensor([[271, 647]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[376.3619, 547.0513]])
# y.unsqueeze(0) tensor([[431, 599]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[339.9750, 508.0936]])
# y.unsqueeze(0) tensor([[404, 582]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[313.0795, 473.4656]])
# y.unsqueeze(0) tensor([[326, 473]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.0007, 449.6230]])
# y.unsqueeze(0) tensor([[152, 398]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[435.5323, 606.3248]])
# y.unsqueeze(0) tensor([[516, 630]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.4586, 418.6689]])
# y.unsqueeze(0) tensor([[316, 464]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.0986, 456.9834]])
# y.unsqueeze(0) tensor([[280, 451]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[216.1055, 386.2485]])
# y.unsqueeze(0) tensor([[227, 379]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[386.3066, 552.0675]])
# y.unsqueeze(0) tensor([[398, 603]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[208.0804, 386.0020]])
# y.unsqueeze(0) tensor([[148, 306]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[164.0502, 332.4279]])
# y.unsqueeze(0) tensor([[193, 361]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[386.2869, 550.3468]])
# y.unsqueeze(0) tensor([[371, 532]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[432.8611, 607.7854]])
# y.unsqueeze(0) tensor([[463, 615]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[185.5318, 358.4664]])
# y.unsqueeze(0) tensor([[195, 346]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[448.8327, 623.7832]])
# y.unsqueeze(0) tensor([[371, 593]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[233.9339, 420.1916]])
# y.unsqueeze(0) tensor([[211, 417]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[214.9229, 388.0540]])
# y.unsqueeze(0) tensor([[150, 312]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[250.2553, 432.8236]])
# y.unsqueeze(0) tensor([[148, 369]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[255.1122, 450.3260]])
# y.unsqueeze(0) tensor([[258, 400]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[411.9360, 581.4269]])
# y.unsqueeze(0) tensor([[392, 537]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[432.8657, 600.9998]])
# y.unsqueeze(0) tensor([[449, 597]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[448.6790, 641.4678]])
# y.unsqueeze(0) tensor([[272, 561]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[393.3275, 567.2699]])
# y.unsqueeze(0) tensor([[348, 546]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[173.8349, 343.3787]])
# y.unsqueeze(0) tensor([[167, 342]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[295.4164, 446.3375]])
# y.unsqueeze(0) tensor([[342, 476]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.7066, 471.5873]])
# y.unsqueeze(0) tensor([[161, 373]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[153.8067, 320.8568]])
# y.unsqueeze(0) tensor([[213, 357]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[181.5472, 349.4442]])
# y.unsqueeze(0) tensor([[253, 368]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[209.7558, 381.0208]])
# y.unsqueeze(0) tensor([[265, 390]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[386.9944, 561.5214]])
# y.unsqueeze(0) tensor([[343, 552]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[161.3541, 327.2133]])
# y.unsqueeze(0) tensor([[154, 275]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[379.9090, 545.5516]])
# y.unsqueeze(0) tensor([[376, 544]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[280.7431, 462.1063]])
# y.unsqueeze(0) tensor([[197, 448]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[423.5029, 595.4128]])
# y.unsqueeze(0) tensor([[393, 618]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[156.1129, 309.9566]])
# y.unsqueeze(0) tensor([[170, 332]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[258.2303, 442.3559]])
# y.unsqueeze(0) tensor([[245, 449]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.5202, 475.0870]])
# y.unsqueeze(0) tensor([[284, 445]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[329.0765, 492.0361]])
# y.unsqueeze(0) tensor([[337, 495]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[226.5516, 383.6499]])
# y.unsqueeze(0) tensor([[286, 404]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[376.9362, 538.5093]])
# y.unsqueeze(0) tensor([[416, 587]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[293.5589, 473.8214]])
# y.unsqueeze(0) tensor([[223, 387]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.1144, 442.5593]])
# y.unsqueeze(0) tensor([[231, 406]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[372.2993, 537.7662]])
# y.unsqueeze(0) tensor([[348, 517]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[426.7056, 602.0203]])
# y.unsqueeze(0) tensor([[468, 599]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[468.8179, 640.0611]])
# y.unsqueeze(0) tensor([[476, 651]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[245.0368, 412.1782]])
# y.unsqueeze(0) tensor([[292, 426]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[260.5724, 433.4262]])
# y.unsqueeze(0) tensor([[150, 284]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[219.8118, 376.8972]])
# y.unsqueeze(0) tensor([[258, 392]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[277.1637, 442.0562]])
# y.unsqueeze(0) tensor([[300, 458]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[403.5186, 563.7452]])
# y.unsqueeze(0) tensor([[465, 629]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[392.6762, 554.0066]])
# y.unsqueeze(0) tensor([[347, 508]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[404.5255, 587.3292]])
# y.unsqueeze(0) tensor([[420, 557]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[401.5356, 577.3485]])
# y.unsqueeze(0) tensor([[435, 560]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[384.2690, 554.6306]])
# y.unsqueeze(0) tensor([[452, 626]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[223.0635, 402.6632]])
# y.unsqueeze(0) tensor([[223, 391]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[241.8852, 405.8521]])
# y.unsqueeze(0) tensor([[302, 466]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[161.1114, 334.6690]])
# y.unsqueeze(0) tensor([[166, 321]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[379.6090, 546.9283]])
# y.unsqueeze(0) tensor([[341, 579]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[251.7658, 431.2766]])
# y.unsqueeze(0) tensor([[144, 284]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[169.6260, 351.3341]])
# y.unsqueeze(0) tensor([[177, 315]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.3988, 464.7139]])
# y.unsqueeze(0) tensor([[298, 497]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[274.6877, 438.8308]])
# y.unsqueeze(0) tensor([[297, 472]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[415.4022, 586.6813]])
# y.unsqueeze(0) tensor([[446, 605]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[269.7736, 434.4288]])
# y.unsqueeze(0) tensor([[294, 469]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[415.7790, 582.6241]])
# y.unsqueeze(0) tensor([[466, 613]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[409.4223, 589.8400]])
# y.unsqueeze(0) tensor([[389, 571]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[224.2010, 388.4246]])
# y.unsqueeze(0) tensor([[143, 325]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[194.9193, 359.9724]])
# y.unsqueeze(0) tensor([[236, 465]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[181.6869, 353.2859]])
# y.unsqueeze(0) tensor([[186, 428]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[217.6327, 379.5378]])
# y.unsqueeze(0) tensor([[256, 397]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[204.6328, 369.8865]])
# y.unsqueeze(0) tensor([[231, 392]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[170.7915, 348.0245]])
# y.unsqueeze(0) tensor([[166, 354]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[197.2232, 372.5723]])
# y.unsqueeze(0) tensor([[264, 438]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[407.6302, 589.9154]])
# y.unsqueeze(0) tensor([[383, 548]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[321.8075, 499.4133]])
# y.unsqueeze(0) tensor([[173, 361]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[239.8591, 398.9554]])
# y.unsqueeze(0) tensor([[264, 439]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[307.1226, 482.9433]])
# y.unsqueeze(0) tensor([[282, 443]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[179.0040, 342.0857]])
# y.unsqueeze(0) tensor([[148, 316]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[432.1272, 623.0488]])
# y.unsqueeze(0) tensor([[371, 570]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[319.0476, 485.8463]])
# y.unsqueeze(0) tensor([[310, 538]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[258.7342, 412.3800]])
# y.unsqueeze(0) tensor([[318, 472]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[188.2014, 360.7402]])
# y.unsqueeze(0) tensor([[269, 418]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[240.3214, 403.2954]])
# y.unsqueeze(0) tensor([[286, 427]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[166.4507, 326.4902]])
# y.unsqueeze(0) tensor([[141, 292]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[417.0001, 600.9586]])
# y.unsqueeze(0) tensor([[423, 612]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[244.2866, 439.7372]])
# y.unsqueeze(0) tensor([[186, 418]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[191.3596, 362.0323]])
# y.unsqueeze(0) tensor([[226, 367]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[253.3842, 427.1584]])
# y.unsqueeze(0) tensor([[273, 441]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[219.2712, 382.0814]])
# y.unsqueeze(0) tensor([[173, 335]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[249.1691, 415.2130]])
# y.unsqueeze(0) tensor([[210, 361]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[327.9306, 486.9553]])
# y.unsqueeze(0) tensor([[496, 614]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[218.3681, 392.5104]])
# y.unsqueeze(0) tensor([[232, 377]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[405.0631, 580.0359]])
# y.unsqueeze(0) tensor([[406, 587]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[296.4534, 467.1862]])
# y.unsqueeze(0) tensor([[286, 447]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[381.0497, 544.9485]])
# y.unsqueeze(0) tensor([[369, 534]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[235.9634, 421.3517]])
# y.unsqueeze(0) tensor([[160, 345]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[267.6494, 426.1591]])
# y.unsqueeze(0) tensor([[304, 469]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[410.4678, 570.8251]])
# y.unsqueeze(0) tensor([[466, 650]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[155.2083, 318.4227]])
# y.unsqueeze(0) tensor([[145, 333]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[390.9694, 562.2101]])
# y.unsqueeze(0) tensor([[411, 615]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[188.5838, 361.6217]])
# y.unsqueeze(0) tensor([[176, 401]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[213.7083, 388.7362]])
# y.unsqueeze(0) tensor([[228, 370]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[278.1244, 463.9369]])
# y.unsqueeze(0) tensor([[277, 488]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[167.3606, 345.3418]])
# y.unsqueeze(0) tensor([[173, 381]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[451.5349, 635.5468]])
# y.unsqueeze(0) tensor([[435, 649]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[405.3553, 579.3192]])
# y.unsqueeze(0) tensor([[347, 559]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[322.9279, 492.6011]])
# y.unsqueeze(0) tensor([[302, 476]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[406.0316, 574.2489]])
# y.unsqueeze(0) tensor([[452, 546]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[402.9917, 565.4207]])
# y.unsqueeze(0) tensor([[461, 622]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[184.5704, 350.5982]])
# y.unsqueeze(0) tensor([[188, 352]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[249.4618, 417.7788]])
# y.unsqueeze(0) tensor([[287, 492]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[364.3125, 525.9664]])
# y.unsqueeze(0) tensor([[360, 538]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[337.5855, 509.4772]])
# y.unsqueeze(0) tensor([[302, 494]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[374.5187, 534.7761]])
# y.unsqueeze(0) tensor([[424, 552]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[417.7150, 596.8111]])
# y.unsqueeze(0) tensor([[432, 623]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[433.3127, 605.2320]])
# y.unsqueeze(0) tensor([[409, 597]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[220.5446, 400.4844]])
# y.unsqueeze(0) tensor([[248, 413]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[433.1662, 603.0061]])
# y.unsqueeze(0) tensor([[490, 627]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[398.7430, 571.5201]])
# y.unsqueeze(0) tensor([[408, 576]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[235.6516, 406.5649]])
# y.unsqueeze(0) tensor([[218, 346]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[239.2380, 407.5915]])
# y.unsqueeze(0) tensor([[262, 414]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[243.1427, 434.0221]])
# y.unsqueeze(0) tensor([[207, 435]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[204.2776, 372.2314]])
# y.unsqueeze(0) tensor([[155, 320]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[407.6241, 570.0803]])
# y.unsqueeze(0) tensor([[460, 614]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[243.8188, 422.3456]])
# y.unsqueeze(0) tensor([[225, 409]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[294.1712, 456.2879]])
# y.unsqueeze(0) tensor([[336, 457]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[200.6561, 379.8042]])
# y.unsqueeze(0) tensor([[199, 356]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[179.9872, 341.0379]])
# y.unsqueeze(0) tensor([[145, 309]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([[417.7459, 589.9781]])
# y.unsqueeze(0) tensor([[465, 589]], dtype=torch.int32)
# y_pred.unsqueeze(0) tensor([